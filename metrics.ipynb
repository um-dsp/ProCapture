# %%
from library.Accessor import Accessor


#Instantiate and Accessor class with a folder containing activations csv/txt
adversarial_sample = Accessor('./adversarial/mnist/FGSM/mnist_1')
begning_sample = Accessor('./begnign/mnist/mnist_1')
ground_truth = Accessor('./Ground_truth/mnist/mnist_1')

    
#Accessor will load and parse the activations from csv/txt to an Activation Class
#Accessor allows you to retreive the acivations by label, prediction, or get_all
#Take a look at accessor for further details

begning_sample_act = begning_sample.get_all(limit=1000)   
adv_sample_act = adversarial_sample.get_all(limit=1000)
ground_truth_act = ground_truth.get_all(limit=1000)

print (f' LEN Begnign: {len(begning_sample_act)} Adv : {len(adv_sample_act)} GT : {len(ground_truth_act)}')
# Out:
# Loaded all activations for ./begnign/mnist/mnist_1
# Loaded all activations for ./adversarial/mnist/FGSM/mnist_1
# Loaded all activations for ./Ground_truth/mnist/mnist_1
#  LEN Begnign: 69 Adv : 54 GT : 63

# %% [markdown]
# ### The Following Represents all the metric experiments discussed in the paper
#  ExpD : Average number of Active Nodes <br>
#  ExpE : Average Activations Weight<br>
#  ExpF : Always Active Nodes <br>
#  ExpG : Frequency Distances<br>
#  ExpH : Dispersation Index<br>
#  ExpI : Entropy Index<br>
#
#  Use Accessor functions to extract the needed activations weather per label ,epr prediction or get all and run the experiment. The next blocks
#  cover different ways the metric could be used

# %%
from library.metrics import expD, expE,expF,expG,expH,expI


begning_sample_act = begning_sample.get_all(limit=1000)   
adv_sample_act = adversarial_sample.get_all(limit=1000)
ground_truth_act = ground_truth.get_all(limit=1000)
expD(begning_sample_act,adv_sample_act,ground_truth_act)
# Out:
# Loaded all activations for ./begnign/mnist/mnist_1
# Loaded all activations for ./adversarial/mnist/FGSM/mnist_1
# Loaded all activations for ./Ground_truth/mnist/mnist_1
#
#  Avg of active nodes   Begnign : 227.14492753623188  Adversarial : 230.72222222222223  Gt : 227.28571428571428
# (227.14492753623188, 230.72222222222223, 227.28571428571428)

# %%
gt = []
ben = []
adv = []
PRED_RANGE = 4

for i in range(PRED_RANGE):
    begning_sample_act = begning_sample.get_label_by_prediction(target_prediction=i,limit=1000)   
    adv_sample_act = adversarial_sample.get_label_by_prediction(target_prediction=i,limit=1000)
    ground_truth_act = ground_truth.get_label_by_prediction(target_prediction=i,limit=1000)
    g,b,a = expE(begning_sample_act,adv_sample_act,ground_truth_act)
    gt.append(g)
    ben.append(b)
    adv.append(a)


from library.utils import plotAcrossPredictions
plotAcrossPredictions(gt,ben,adv,PRED_RANGE)
# Out:
# Loaded 6 Activations for Prediction : 0
# Loaded 5 Activations for Prediction : 0
# Loaded 6 Activations for Prediction : 0
#  Average activation weights of   Ben : 145.83377588937677  Adv : 142.22383102446793 GT : 140.66844347665707
# Loaded 10 Activations for Prediction : 1
# Loaded 9 Activations for Prediction : 1
# Loaded 8 Activations for Prediction : 1
#  Average activation weights of   Ben : 133.0029655840993  Adv : 133.0450924643212 GT : 142.94315466433764
# Loaded 6 Activations for Prediction : 2
# Loaded 5 Activations for Prediction : 2
# Loaded 4 Activations for Prediction : 2
#  Average activation weights of   Ben : 136.16980977406106  Adv : 126.6674809268117 GT : 204.0973606303334
# Loaded 7 Activations for Prediction : 3
# Loaded 5 Activations for Prediction : 3
# Loaded 8 Activations for Prediction : 3
#  Average activation weights of   Ben : 133.80504481749875  Adv : 155.20185501128435 GT : 176.35776230841876

# %%
begning_sample_act = begning_sample.get_all(limit=1000)   
adv_sample_act = adversarial_sample.get_all(limit=1000)
ground_truth_act = ground_truth.get_all(limit=1000)
expF(begning_sample_act,adv_sample_act,ground_truth_act)
# Out:
# Loaded all activations for ./begnign/mnist/mnist_1
# Loaded all activations for ./adversarial/mnist/FGSM/mnist_1
# Loaded all activations for ./Ground_truth/mnist/mnist_1
# Prediction None
# number of nodes always active benign : 5
# [853, 910, 988, 1021, 1112]
# number of nodes always active Adv : 13
# [784, 841, 852, 853, 898, 910, 957, 988, 1008, 1021, 1084, 1112, 1141]
# number of nodes always active GT : 766
# ...

# %%
begning_sample_act = begning_sample.get_label_by_prediction(target_prediction=i,limit=1000)   
adv_sample_act = adversarial_sample.get_label_by_prediction(target_prediction=i,limit=1000)
ground_truth_act = ground_truth.get_label_by_prediction(target_prediction=i,limit=1000)
expG(begning_sample_act,adv_sample_act,ground_truth_act)
# Out:
# Loaded 6 Activations for Prediction : 2
# Loaded 5 Activations for Prediction : 2
# Loaded 4 Activations for Prediction : 2
# distance between Benign and Gt: 0.14668049792531124
# distance between Adversarial and Gt: 0.15929460580912863
# (0.14668049792531124, 0.15929460580912863)

# %%
ben = []
ad = []
gt = []
PRED_RANGE = 3
for i in range(PRED_RANGE):
    begning_sample_act = begning_sample.get_label_by_prediction(target_prediction=i,limit=1000)   
    adv_sample_act = adversarial_sample.get_label_by_prediction(target_prediction=i,limit=1000)
    ground_truth_act = ground_truth.get_label_by_prediction(target_prediction=i,limit=1000)
    b,a,g = expH(begning_sample_act,adv_sample_act,ground_truth_act)
    ben.append(b)
    ad.append(a)
    gt.append(g)

plotAcrossPredictions(gt,ben,ad,PRED_RANGE)
# Out:
# Loaded 6 Activations for Prediction : 0
# Loaded 5 Activations for Prediction : 0
# Loaded 6 Activations for Prediction : 0
# dispersation index Benign : 113403043.33333334 Adv : 127808838.39999999 GT : 113964800.66666666
# Loaded 10 Activations for Prediction : 1
# Loaded 9 Activations for Prediction : 1
# Loaded 8 Activations for Prediction : 1
# dispersation index Benign : 22885892.55 Adv : 23218332.388888888 GT : 30026082.625
# Loaded 6 Activations for Prediction : 2
# Loaded 5 Activations for Prediction : 2
# Loaded 4 Activations for Prediction : 2
# dispersation index Benign : 57805082.0 Adv : 62355761.6 GT : 122550083.5

# %%
ben = []
ad = []
gt = []
PRED_RANGE = 3
for i in range(PRED_RANGE):
    begning_sample_act = begning_sample.get_label_by_prediction(target_prediction=i,limit=1000)   
    adv_sample_act = adversarial_sample.get_label_by_prediction(target_prediction=i,limit=1000)
    ground_truth_act = ground_truth.get_label_by_prediction(target_prediction=i,limit=1000)
    b,a,g = expI(begning_sample_act,adv_sample_act,ground_truth_act)
    ben.append(b)
    ad.append(a)
    gt.append(g)

plotAcrossPredictions(gt,ben,ad,PRED_RANGE)
# Out:
# Loaded 6 Activations for Prediction : 0
# Loaded 5 Activations for Prediction : 0
# Loaded 6 Activations for Prediction : 0
# Entropy index   Benign : 1.6916422970276241 Adv : 1.6742914861378728 GT : 1.8414299699248613
# Loaded 10 Activations for Prediction : 1
# Loaded 9 Activations for Prediction : 1
# Loaded 8 Activations for Prediction : 1
# Entropy index   Benign : 1.5212866455026859 Adv : 1.5320953970237658 GT : 1.60594528331451
# Loaded 6 Activations for Prediction : 2
# Loaded 5 Activations for Prediction : 2
# Loaded 4 Activations for Prediction : 2
# Entropy index   Benign : 1.6750054954690194 Adv : 1.632408453745034 GT : 1.7436578901532098
